# %%
print('Aditya')
# Out:
# Aditya

# %%
print('Aditya')
print('Hello World')
print('Goodbye!!!')
# Out:
# Aditya
# Hello World
# Goodbye!!!

# %%
a = 35

# %%
print(a)
# Out:
# 35

# %%
type(a)
# Out:
# int

# %%
b = '35'

# %%
type(b)
# Out:
# str

# %%
c = 35.00

# %%
type(c)
# Out:
# float

# %%
a + 50
# Out:
# 85

# %%
result = a + 50

# %%
print(result)
# Out:
# 85

# %%
num = 377239864824691878478347336928743864853638648364836583629364836464

# %%
print(num)
# Out:
# 377239864824691878478347336928743864853638648364836583629364836464

# %%
num1 = 3287689 ** 123
print(num1)
# Out:
# ...

# %%
# float data type

# %%
f = 56.67
print(f)
# Out:
# 56.67

# %%
type(f)
# Out:
# float

# %%
result = f * 23.20
print(result)
# Out:
# 1314.744

# %%
num3 = 17e3
print(num3)
# Out:
# 17000.0

# %%
type(num3)
# Out:
# float

# %%
# string data type

# %%
name = "Aditya"
print(name)
# Out:
# Aditya

# %%
type(name)
# Out:
# str

# %%
sent = 'I like Python Programming'
print(sent)
# Out:
# I like Python Programming

# %%
sent = 'I like "Python" Programming'
print(sent)
# Out:
# I like "Python" Programming

# %%
# multiple assignment

# %%
num1 , num2, num3 = 34, 56.00, 30

# %%
print(num1, num2, num3)
# Out:
# 34 56.0 30

# %%
num1 = 10
num2 = 20
addition = num1 + num2
print(addition)
# Out:
# 30

# %%
num1 = 10; num2 = 20; addition = num1 + num2; print(addition)
# Out:
# 30

# %%
# String Operations

# %%
name = 'Aditya'

# %%
name.lower()
# Out:
# 'aditya'

# %%
x = name.upper()
print(x)
# Out:
# ADITYA

# %%
name.swapcase()
# Out:
# 'aDITYA'

# %%
len(name)
# Out:
# 6

# %%
name1 = 'aditya '
len(name1)
# Out:
# 7

# %%
name.isdigit()
# Out:
# False

# %%
name.isalpha()
# Out:
# True

# %%
num = '3456t'

# %%
num.isdigit()
# Out:
# False

# %%
num.isalpha()
# Out:
# False

# %%
s1 = ' ADITYA '

# %%
s1.lstrip()
# Out:
# 'ADITYA '

# %%
s1.rstrip()
# Out:
# ' ADITYA'

# %%
s1.strip()
# Out:
# 'ADITYA'

# %%
s1.startswith('A')
# Out:
# False

# %%
s1.startswith(' Ad')
# Out:
# False

# %%
s1.endswith(' ')
# Out:
# True

# %%
s1.replace('I', 'ee')
# Out:
# ' ADeeTYA '

# %%
s1.replace(' ', '@')
# Out:
# '@ADITYA@'

# %%
s2 = 'Pune'

# %%
s2.find('P') # indexing starts from 0
# Out:
# 0

# %%
s2.find('O')  # -1 -> not there
# Out:
# -1

# %%
dir(s2)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(s1.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
# string concatenation

str1 = 'Good'
str2 = 'Bye!!!'

# %%
s = str1 + str2
print(s)
# Out:
# GoodBye!!!

# %%
s = str1 + ' ' + str2
print(s)
# Out:
# Good Bye!!!

# %%
str1 * 5
# Out:
# 'GoodGoodGoodGoodGood'

# %%
# escape sequence
print('good\nbye')
# Out:
# good
# bye

# %%
print('good\tbye')
# Out:
# good	bye

# %%
print('good\'bye')
# Out:
# good'bye

# %%
print('good\"bye')
# Out:
# good"bye

# %%
print('good \b"bye')
# Out:
# "bye

# %%
# doc string

k = '''this is first statement
this is second statement
this is third statement'''

# %%
print(k)
# Out:
# this is first statement
# this is second statement
# this is third statement

# %%
# ASCII

# %%
ord('A')
# Out:
# 65

# %%
ord('@')
# Out:
# 64

# %%
ord('a')
# Out:
# 97

# %%
chr(45)
# Out:
# '-'

# %%
chr(65)
# Out:
# 'A'

# %%
chr(178)
# Out:
# '²'

# %%
'x' + chr(178)
# Out:
# 'x²'

# %%
 # print function

# %%
name = 'Aditya'
marks = 73
loc = 'Pune'

# %%
print('my name is', name, 'and marks are', marks, 'I live in', loc)
# Out:
# my name is Aditya and marks are 73 I live in Pune

# %%
# formatted print

print('my name is %s and marks are %f' %(name, marks))
# Out:
# my name is Aditya and marks are 73.000000

# %%
print('my name is %s and marks are %.3f' %(name, marks))
# Out:
# my name is Aditya and marks are 73.000

# %%
print(name, marks, loc)
# Out:
# Aditya 73 Pune

# %%
print(name, marks, loc, sep = '\n')
# Out:
# Aditya
# 73
# Pune

# %%
print(name, marks, loc, sep = '*')
# Out:
# Aditya*73*Pune

# %%
print(name, marks, loc, end = '*')
# Out:
# Aditya 73 Pune*

# %% [markdown]
# # Operators

# %%
# Arithmetic Operators

# %%
50 + 70
# Out:
# 120

# %%
70 - 6
# Out:
# 64

# %%
20 * 2
# Out:
# 40

# %%
20 / 10
# Out:
# 2.0

# %%
20 / 11
# Out:
# 1.8181818181818181

# %%
200 / 11
# Out:
# 18.181818181818183

# %%
200 // 11 # floor division
# Out:
# 18

# %%
200 % 11 # remainder
# Out:
# 2

# %%
# Relational

# %%
num1 = 45
num2 = 50

# %%
num1 > num2
# Out:
# False

# %%
num1 < num2
# Out:
# True

# %%
num1 == num2
# Out:
# False

# %%
num1 != num2
# Out:
# True

# %%
 num1 >= num2
# Out:
# False

# %%
num1 <= num2
# Out:
# True

# %%
# Assignment

# %%
num1 = 10

# %%
num1 += 10  # => num1 = num1 + 10
print(num1)
# Out:
# 20

# %%
num1 -= 5

# %%
print(num1)
# Out:
# 15

# %%
# Logical

# %%
num1 < num2 and num1 > num2
# Out:
# False

# %%
num1 < num2 or num1 > num2
# Out:
# True

# %%
# membership

# %%
name = 'Aditya'

# %%
'A' in name
# Out:
# True

# %%
'Z' in name
# Out:
# False

# %%
# type casting

# %%
num1 = 70
num2 = 77

# %%
ad = num1 + float(num2)
ad
# Out:
# 147.0

# %%
num1 = 70
num2 = 77.50

# %%
ad = num1 + int(num2)
ad
# Out:
# 147

# %%
s = '3456'

# %%
type(s)
# Out:
# str

# %%
s * 3
# Out:
# '345634563456'

# %%
int(s) * 3
# Out:
# 10368

# %%
# user input

# %%
a = 10
b = 20
add = a + b
print(add)
# Out:
# 30

# %%
a = input('enter the first number')
# Out:
# enter the first number100

# %%
print(a)
# Out:
# 100

# %%
type(a)
# Out:
# str

# %%
a = int(input('enter the first number'))
# Out:
# enter the first number100

# %%
type(a)
# Out:
# int

# %%
a1 = int(input('enter the first no. '))
a2 = int(input('enter the second no. '))

add = a1 + a2
print('The addition is ', add)
# Out:
# enter the first no. 10
# enter the second no. 20
# The addition is  30

# %%
# cube, square, floor division, remainder
