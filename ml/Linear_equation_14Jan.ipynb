# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5,0,0.25)

# %%
x      # consider it as dependent variable
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25])

# %%
# y -> independent variable

y = x * 2.3 + 5.91

# %%
y
# Out:
# array([-5.59 , -5.015, -4.44 , -3.865, -3.29 , -2.715, -2.14 , -1.565,
#        -0.99 , -0.415,  0.16 ,  0.735,  1.31 ,  1.885,  2.46 ,  3.035,
#         3.61 ,  4.185,  4.76 ,  5.335])

# %%
plt.plot(x, y)
