# %%
# dataset: Petrol_Consumption.csv
# Location: https://mitu.co.in/dataset

# %% [markdown]
# #### import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### import the dataset

# %%
df = pd.read_csv('petrol_consumption.csv')
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %% [markdown]
# #### Separate input data and output data

# %%
# input
x = df.drop('Petrol_Consumption', axis = 1)

# output
y = df['Petrol_Consumption']

# %% [markdown]
# #### cross validation

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.25,
                                                   random_state=0)

# %%
x_train.shape
# Out:
# (36, 4)

# %%
x_test.shape
# Out:
# (12, 4)

# %% [markdown]
# #### Build the model

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state= 0)

# %%
reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# #### prediction on unseen data

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([541., 498., 628., 628., 628., 644., 628., 649., 414., 464., 414.,
#        628.])

# %%
result =pd.DataFrame({
    'actual': y_test,
    'predicted': y_pred
})

# %%
result
# Out:
#     actual  predicted
# 29     534      541.0
# 4      410      498.0
# 26     577      628.0
# 30     571      628.0
# 32     577      628.0
# 37     704      644.0
# 34     487      628.0
# 40     587      649.0
# 7      467      414.0
# 10     580      464.0
# 11     471      414.0
# 31     554      628.0

# %% [markdown]
# #### Performance Evaluation

# %%
# mean absolute error
np.mean(abs(y_test - y_pred))
# Out:
# 68.08333333333333

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, y_pred) * 100
# Out:
# 12.94003614849453

# %%
# mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 5713.25

# %% [markdown]
# #### predict on unseen data

# %%
new = [[9.0, 3571, 1976, 0.839]]

# %%
reg.predict(new)
# Out:
# /home/aditya/anaconda3/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([640.])
