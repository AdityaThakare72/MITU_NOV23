# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.25)

# %%
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
# consider x as ur input => y = mx + c
# lets take equation of line
y = 1.6 * x + 3.10

# %%
y    # output
# Out:
# array([-4.9, -4.5, -4.1, -3.7, -3.3, -2.9, -2.5, -2.1, -1.7, -1.3, -0.9,
#        -0.5, -0.1,  0.3,  0.7,  1.1,  1.5,  1.9,  2.3,  2.7,  3.1,  3.5,
#         3.9,  4.3,  4.7,  5.1,  5.5,  5.9,  6.3,  6.7,  7.1,  7.5,  7.9,
#         8.3,  8.7,  9.1,  9.5,  9.9, 10.3, 10.7])

# %%
plt.plot(x,y)

# %%
# for polynomial

# %%
x = np.arange(1, 5, 0.25)

# %%
y = 1 * (x ** 5) + 0   # degree of this equation = 5

# %%
plt.plot(x, y)
