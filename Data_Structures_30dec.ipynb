# %% [markdown]
# # List

# %%
l1 = [445,64,6,67,2,55]

# %%
l1
# Out:
# [445, 64, 6, 67, 2, 55]

# %%
type(l1)
# Out:
# list

# %%
# indexing=> starts from 0 and negative indexing starts from -1
l1[0]
# Out:
# 445

# %%
l1[-1]
# Out:
# 55

# %%
# lists are heterogeneous
l2 = [45,34,67,'Aditya', 56.34]
l2
# Out:
# [45, 34, 67, 'Aditya', 56.34]

# %%
num = [45,34,26,87,97,54,34]
num
# Out:
# [45, 34, 26, 87, 97, 54, 34]

# %%
# mutable
num[1]=100

# %%
num
# Out:
# [45, 100, 26, 87, 97, 54, 34]

# %%
# slicing
num[1:6]
# Out:
# [100, 26, 87, 97, 54]

# %%
num[6:1]
# Out:
# []

# %%
num[1:-1]
# Out:
# [100, 26, 87, 97, 54]

# %%
num[:-1]
# Out:
# [45, 100, 26, 87, 97, 54]

# %%
num[1:]
# Out:
# [100, 26, 87, 97, 54, 34]

# %%
num[:]
# Out:
# [45, 100, 26, 87, 97, 54, 34]

# %%
num[1:4] = [45,35,67]
num
# Out:
# [45, 45, 35, 67, 97, 54, 34]

# %%
# in operator
56 in num
# Out:
# False

# %%
35 in num
# Out:
# True

# %%
# delete
del num[1]
num
# Out:
# [45, 35, 67, 97, 54, 34]

# %%
# arithmetic operator

num * 2
# Out:
# [45, 35, 67, 97, 54, 34, 45, 35, 67, 97, 54, 34]

# %%
num
# Out:
# [45, 35, 67, 97, 54, 34]

# %%
num + [1]
# Out:
# [45, 35, 67, 97, 54, 34, 1]

# %%
num + [56,78,54]
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54]

# %%
num += [56,78,54]
num
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54]

# %%
# find the odd elements using for loop

for n in num:
    if n % 2 == 1:
        print(n, end = ' ')
# Out:
# 45 35 67 97

# %%
# list comprehension - map

new = [n/2 for n in num]
new
# Out:
# [22.5, 17.5, 33.5, 48.5, 27.0, 17.0, 28.0, 39.0, 27.0]

# %%
# filter

new1 = [n for n in num if n > 50]
new1
# Out:
# [67, 97, 54, 56, 78, 54]

# %%
# filter the odd elements
new2 = [n for n in num if n % 2 ==1]
new2
# Out:
# [45, 35, 67, 97]

# %%
# filter the numbers whose last digit is not 7 from num

new2 = [n for n in num if n % 10 != 7]
new2
# Out:
# [45, 35, 54, 34, 56, 78, 54]

# %%
# empty list

e = []

# %%
e
# Out:
# []

# %%
e += [10]
e
# Out:
# [10]

# %%
# list of list
list1 = [[43,45,65],[34,65],[65,32,7],5,32,89,65]
list1
# Out:
# [[43, 45, 65], [34, 65], [65, 32, 7], 5, 32, 89, 65]

# %%
list1[2]
# Out:
# [65, 32, 7]

# %%
list1[2][1]
# Out:
# 32

# %%
# Assign list elements to variables
t = [45,34,67,90]

# %%
a, b, c, d = t

# %%
a
# Out:
# 45

# %%
b
# Out:
# 34

# %%
c
# Out:
# 67

# %%
d
# Out:
# 90

# %% [markdown]
# #### functions on list

# %%
sum(t)
# Out:
# 236

# %%
max(t)
# Out:
# 90

# %%
min(t)
# Out:
# 34

# %%
sorted(t)
# Out:
# [34, 45, 67, 90]

# %%
sorted(t, reverse=True)
# Out:
# [90, 67, 45, 34]

# %%
name ='Aditya'
list(name)
# Out:
# ['A', 'd', 'i', 't', 'y', 'a']

# %% [markdown]
# #### methods

# %%
num
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54]

# %%
num.append(100)  # add an element at the end
num
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54, 100]

# %%
x = [67,43,78]
y = [43,45,90]

# %%
x.append([30,20])
y.extend([30,20])

# %%
x
# Out:
# [67, 43, 78, [30, 20]]

# %%
y
# Out:
# [43, 45, 90, 30, 20]

# %%
# copy

z = x  # with this when we change x-> z will also get changed
z
# Out:
# [67, 43, 78, [30, 20]]

# %%
x[2]= 3

# %%
x
# Out:
# [67, 43, 3, [30, 20]]

# %%
z
# Out:
# [67, 43, 3, [30, 20]]

# %%
q = x.copy()  # q is a copy of x but if change x later on...q wont change
q
# Out:
# [67, 43, 3, [30, 20]]

# %%
x[3]=5
x
# Out:
# [67, 43, 3, 5]

# %%
q
# Out:
# [67, 43, 3, [30, 20]]

# %%
z
# Out:
# [67, 43, 3, 5]

# %%
# insert

num
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54, 100]

# %%
num.insert(2,10)
num
# Out:
# [34, 35, 10, 45, 54, 54, 56, 78, 97]

# %%
# remove
num.remove(10)
num
# Out:
# [45, 35, 67, 97, 54, 34, 56, 78, 54, 100]

# %%
num.pop(2)
# Out:
# 67

# %%
num.pop()  # will delete the last element
# Out:
# 100

# %%
num
# Out:
# [45, 35, 97, 54, 34, 56, 78, 54]

# %%
num.index(56)  # will give the index of that value
# Out:
# 5

# %%
num.count(54)
# Out:
# 2

# %%
num.sort()

# %%
num
# Out:
# [34, 35, 45, 54, 54, 56, 78, 97]

# %%
num
# Out:
# [34, 35, 10, 45, 54, 54, 56, 78, 97]

# %%
# take the user input as -> number of elements and elements
# create a list of those elements
# empty list, append

num = []
count = int(input('Enter the number of elements '))
for n in range(count):
    x = int(input('enter the element '))
    num.append(x)
    
print('List:', num)
# Out:
# Enter the number of elements 3
# enter the element 45
# enter the element 767
# enter the element 65
# List: [45, 767, 65]

# %% [markdown]
# # Tuple

# %%
t1 = (34,36,67,45)

# %%
t1
# Out:
# (34, 36, 67, 45)

# %%
type(t1)
# Out:
# tuple

# %%
t1[1]
# Out:
# 36

# %%
t1[-1]
# Out:
# 45

# %%
# immutable
t1[1] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 # immutable
# ----> 2 t1[1] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
min(t1)
# Out:
# 34

# %%
max(t1)
# Out:
# 67

# %%
sorted(t1)
# Out:
# [34, 36, 45, 67]

# %%
x = [45,332,56,78]

# %%
y = tuple(x)  # converting ur list to tuple
y
# Out:
# (45, 332, 56, 78)

# %%
t1
# Out:
# (34, 36, 67, 45)

# %%
t1 += (45,68,30)
t1
# Out:
# (34, 36, 67, 45, 45, 68, 30)

# %%
t1.count(45)
# Out:
# 2

# %%
t1.index(45)
# Out:
# 3

# %%
45 in t1
# Out:
# True

# %%
773 in t1
# Out:
# False

# %% [markdown]
# # Set

# %%
s1 = {45,67,89,43,23}

# %%
s1
# Out:
# {23, 43, 45, 67, 89}

# %%
type(s1)
# Out:
# set

# %%
s1.add(56)
s1
# Out:
# {23, 43, 45, 56, 67, 89}

# %%
s1[2] # unordered
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 s1[2]
#
# TypeError: 'set' object is not subscriptable

# %%
s2 = {56,45,67,89,56,45,56}
s2   # no duplicate values are allowed
# Out:
# {45, 56, 67, 89}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %% [markdown]
# # Dictionary

# %%
d1 = {1:78, 2:89, 3:78, 4:73}  # key value pairs
print(d1)
# Out:
# {1: 78, 2: 89, 3: 78, 4: 73}

# %%
d1[2] # accessing a value assigned to a key
# Out:
# 89

# %%
d1[5] = 'Aditya'  # adding a new key
d1
# Out:
# {1: 78, 2: 89, 3: 78, 4: 73, 5: 'Aditya'}

# %%
d1[3] = 'Hello'  # changing the value of a key
d1
# Out:
# {1: 78, 2: 89, 3: 'Hello', 4: 73, 5: 'Aditya'}

# %%
d1['a'] = 'Light'
d1
# Out:
# {1: 78, 2: 89, 3: 'Hello', 4: 73, 5: 'Aditya', 'a': 'Light'}

# %%
d1['b'] = ['Aditya','Light',45]

# %%
d1
# Out:
# {1: 78,
#  2: 89,
#  3: 'Hello',
#  4: 73,
#  5: 'Aditya',
#  'a': 'Light',
#  'b': ['Aditya', 'Light', 45]}

# %%
list(d1.values())
# Out:
# [78, 89, 'Hello', 73, 'Aditya', 'Light', ['Aditya', 'Light', 45]]

# %%
list(d1.keys())
# Out:
# [1, 2, 3, 4, 5, 'a', 'b']

# %%
list(d1.items())
# Out:
# [(1, 78),
#  (2, 89),
#  (3, 'Hello'),
#  (4, 73),
#  (5, 'Aditya'),
#  ('a', 'Light'),
#  ('b', ['Aditya', 'Light', 45])]

# %%
print(len(d1))
# Out:
# 7

# %%
keys = d1.keys()
keys
# Out:
# dict_keys([1, 2, 3, 4, 5, 'a', 'b'])

# %%
values = d1.values()
values
# Out:
# dict_values([78, 89, 'Hello', 73, 'Aditya', 'Light', ['Aditya', 'Light', 45]])

# %%
# merging

d2 = {7:67, 8:54, 9:80}

d1.update(d2)

# %%
d1
# Out:
# {1: 78,
#  2: 89,
#  3: 'Hello',
#  4: 73,
#  5: 'Aditya',
#  'a': 'Light',
#  'b': ['Aditya', 'Light', 45],
#  7: 67,
#  8: 54,
#  9: 80}

# %%
del d1[8]
d1
# Out:
# {1: 78,
#  2: 89,
#  3: 'Hello',
#  4: 73,
#  5: 'Aditya',
#  'a': 'Light',
#  'b': ['Aditya', 'Light', 45],
#  7: 67,
#  9: 80}

# %%
# checking if a key is present

if 5 in d1:
    print('found!')
# Out:
# found!

# %%
d1.clear()

# %%
d1
# Out:
# {}
